# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading csv file
df = pd.read_csv("C:/Users/hands/Downloads/sample_dataset.csv", encoding='latin1')

# %%
df
# Out:
#        Customer ID       Name    Surname Gender   Birthdate  \
# 0           752858       Sean  Rodriguez      F  20-10-2002
# 1            26381   Michelle     Phelps    NaN  24-10-1985
# 2           305449      Jacob   Williams      M  25-10-1981
# 3           988259     Nathan     Snyder      M  26-10-1977
# 4           764762    Crystal      Knapp      F  02-11-1951
# ...            ...        ...        ...    ...         ...
# 49995       891845  Christine      Leach      F  21-10-1997
# 49996       800560       Anna      Allen      F  21-10-1999
# 49997       133285     Nicole   Franklin      M  26-10-1979
# 49998       616122      Maria     Keller      M  25-10-1981
# 49999       832184      Billy     Walker      F  31-10-1958
#
#        Transaction Amount        Date                 Merchant Name  \
# 0                   35.47  03-04-2023                 Smith-Russell
# 1                 2552.72  17-07-2023        Peck, Spence and Young
# ...

# %%
df.shape
# Out:
# (50000, 9)

# %%
df.head()
# Out:
#    Customer ID      Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858      Sean  Rodriguez      F  20-10-2002               35.47
# 1        26381  Michelle     Phelps    NaN  24-10-1985             2552.72
# 2       305449     Jacob   Williams      M  25-10-1981              115.97
# 3       988259    Nathan     Snyder      M  26-10-1977               11.31
# 4       764762   Crystal      Knapp      F  02-11-1951               62.21
#
#          Date               Merchant Name     Category
# 0  03-04-2023               Smith-Russell     Cosmetic
# 1  17-07-2023      Peck, Spence and Young       Travel
# 2  20-09-2023                  Steele Inc     Clothing
# 3  11-01-2023  Wilson, Wilson and Russell     Cosmetic
# 4  13-06-2023               Palmer-Hinton  Electronics

# %%
df.tail()
# Out:
#        Customer ID       Name   Surname Gender   Birthdate  \
# 49995       891845  Christine     Leach      F  21-10-1997
# 49996       800560       Anna     Allen      F  21-10-1999
# 49997       133285     Nicole  Franklin      M  26-10-1979
# 49998       616122      Maria    Keller      M  25-10-1981
# 49999       832184      Billy    Walker      F  31-10-1958
#
#        Transaction Amount        Date                 Merchant Name  Category
# 49995              108.74  30-08-2023                 Alexander Ltd    Market
# 49996              133.66  03-05-2023                 Knapp-Calhoun  Cosmetic
# 49997              464.29  12-02-2023  Cantrell, Haynes and Ballard    Market
# 49998              472.57  25-03-2023     Wilson, Jackson and Beard    Market
# 49999              270.67  20-05-2023                     Combs LLC    Market

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         50000 non-null  int64
#  1   Name                50000 non-null  object
#  2   Surname             50000 non-null  object
#  3   Gender              44953 non-null  object
#  4   Birthdate           50000 non-null  object
#  5   Transaction Amount  50000 non-null  float64
#  6   Date                50000 non-null  object
#  7   Merchant Name       50000 non-null  object
#  8   Category            50000 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.4+ MB

# %%
df.describe()
# Out:
#         Customer ID  Transaction Amount
# count   50000.00000        50000.000000
# mean   500136.79696          442.119239
# std    288232.43164          631.669724
# min        29.00000            5.010000
# 25%    251191.50000           79.007500
# 50%    499520.50000          182.195000
# 75%    749854.25000          470.515000
# max    999997.00000         2999.880000

# %%
df.columns
# Out:
# Index(['Customer ID', 'Name', 'Surname', 'Gender', 'Birthdate',
#        'Transaction Amount', 'Date', 'Merchant Name', 'Category'],
#       dtype='object')

# %% [markdown]
#  Data Cleaning

# %%
#NULL values 
df.isnull().sum()
# Out:
# Customer ID              0
# Name                     0
# Surname                  0
# Gender                5047
# Birthdate                0
# Transaction Amount       0
# Date                     0
# Merchant Name            0
# Category                 0
# dtype: int64

# %%
#removing NULL values
new_data= df.dropna()

# %%
new_data.isnull().sum()
# Out:
# Customer ID           0
# Name                  0
# Surname               0
# Gender                0
# Birthdate             0
# Transaction Amount    0
# Date                  0
# Merchant Name         0
# Category              0
# dtype: int64

# %%
new_data.head()
# Out:
#    Customer ID     Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858     Sean  Rodriguez      F  20-10-2002               35.47
# 2       305449    Jacob   Williams      M  25-10-1981              115.97
# 3       988259   Nathan     Snyder      M  26-10-1977               11.31
# 4       764762  Crystal      Knapp      F  02-11-1951               62.21
# 5       576539   Monica   Bartlett      F  20-10-2001               99.14
#
#          Date               Merchant Name     Category
# 0  03-04-2023               Smith-Russell     Cosmetic
# 2  20-09-2023                  Steele Inc     Clothing
# 3  11-01-2023  Wilson, Wilson and Russell     Cosmetic
# 4  13-06-2023               Palmer-Hinton  Electronics
# 5  24-08-2023      Tran, Torres and Joyce     Cosmetic

# %%
#converting Name and Surname columns into str
new_data['Name'] = new_data['Name'].astype(str)
new_data['Surname'] = new_data['Surname'].astype(str)
# Out:
# C:\Users\hands\AppData\Local\Temp\ipykernel_10528\1304121584.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Name'] = new_data['Name'].astype(str)
# C:\Users\hands\AppData\Local\Temp\ipykernel_10528\1304121584.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Surname'] = new_data['Surname'].astype(str)

# %%
#concatenation of two columns
new_data['Full Name']= new_data['Name']+ '' + new_data['Surname']

def Names(row):
     return row['Name']+ '' + row['Surname']

new_data['Full Name']= new_data.apply(Names, axis=1)
new_data.head()
# Out:
# C:\Users\hands\AppData\Local\Temp\ipykernel_10528\2950592829.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Full Name']= new_data['Name']+ '' + new_data['Surname']
# C:\Users\hands\AppData\Local\Temp\ipykernel_10528\2950592829.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Full Name']= new_data.apply(Names, axis=1)
#    Customer ID     Name    Surname Gender   Birthdate  Transaction Amount  \
# ...

# %%
new_data.head()
# Out:
#    Customer ID     Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858     Sean  Rodriguez      F  20-10-2002               35.47
# 2       305449    Jacob   Williams      M  25-10-1981              115.97
# 3       988259   Nathan     Snyder      M  26-10-1977               11.31
# 4       764762  Crystal      Knapp      F  02-11-1951               62.21
# 5       576539   Monica   Bartlett      F  20-10-2001               99.14
#
#          Date               Merchant Name     Category       Full Name
# 0  03-04-2023               Smith-Russell     Cosmetic   SeanRodriguez
# 2  20-09-2023                  Steele Inc     Clothing   JacobWilliams
# 3  11-01-2023  Wilson, Wilson and Russell     Cosmetic    NathanSnyder
# 4  13-06-2023               Palmer-Hinton  Electronics    CrystalKnapp
# 5  24-08-2023      Tran, Torres and Joyce     Cosmetic  MonicaBartlett

# %%
#Extract the month from the date
new_data['Date'] = pd.to_datetime(new_data['Date'])

new_data['Month'] = new_data['Date'].dt.month
new_data.head()
# Out:
# C:\Users\hands\AppData\Local\Temp\ipykernel_10528\2250483838.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   new_data['Date'] = pd.to_datetime(new_data['Date'])
# C:\Users\hands\AppData\Local\Temp\ipykernel_10528\2250483838.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Date'] = pd.to_datetime(new_data['Date'])
# C:\Users\hands\AppData\Local\Temp\ipykernel_10528\2250483838.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Total Monthly Transactions
results= new_data.groupby('Month').sum()
results
# Out:
# C:\Users\hands\AppData\Local\Temp\ipykernel_10528\169144673.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results= new_data.groupby('Month').sum()
#        Customer ID  Transaction Amount
# Month
# 1       2288344862          1978289.21
# 2       2016188204          1793728.00
# 3       2298964886          2021923.57
# 4       2200854017          2009588.04
# 5       2308395161          2088882.23
# 6       2212827832          1880485.09
# 7       2265914459          2020354.78
# 8       2264979230          1979762.25
# 9       2148330170          1872410.03
# 10       910620527           832087.93
# 11       783957300           698733.88
# 12       790205453           737758.04

# %%
#bar plot on months vs Transactions 
months =range(1,13)

plt.plot(months, results['Transaction Amount'])
plt.xticks(months)
plt.xlabel('month numer')
plt.ylabel('Transactions')
plt.show()

# %%
#Gender Transactions
results= new_data.groupby('Gender').sum()
results
# Out:
# C:\Users\hands\AppData\Local\Temp\ipykernel_10528\494031702.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results= new_data.groupby('Gender').sum()
#         Customer ID  Transaction Amount   Month
# Gender
# F       11397299984         10119120.24  129254
# M       11092282117          9794882.81  125814

# %%
#New_Data after Cleaning
new_data.shape
# Out:
# (44953, 11)

# %% [markdown]
# Exploratory Data Analysis-(EDA)

# %%
# plotting a bar chart for Gender vs Category Count
ax = sns.countplot(x = 'Gender',data = new_data, hue='Category')
sns.set(rc={'figure.figsize':(30,15)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#category wise count 
ax = sns.countplot(x = 'Category',data = new_data)
sns.set(rc={'figure.figsize':(15,10)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for Date vs Top 10 Transaction Amounts      
sales_data = new_data.groupby(['Date'], as_index=False)['Transaction Amount'].sum().sort_values(by='Transaction Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(40,20)})
sns.barplot(data = sales_data, x = 'Date',y= 'Transaction Amount')
# Out:
# <AxesSubplot: xlabel='Date', ylabel='Transaction Amount'>

# %%
# plotting a bar chart for Date vs Buttom 10 Transaction Amounts      
sales_data = new_data.groupby(['Date'], as_index=False)['Transaction Amount'].sum().sort_values(by='Transaction Amount', ascending=False).tail(10)
sns.set(rc={'figure.figsize':(40,20)})
sns.barplot(data = sales_data, x = 'Date',y= 'Transaction Amount')
# Out:
# <AxesSubplot: xlabel='Date', ylabel='Transaction Amount'>

# %% [markdown]
# By this customer Transaction Analysis, Females made the highest number of transactions.The Travel category records the most transactions, May month having the highest transaction volume throughout the year and the lowest number of transactions occurred in November month.
